# %% [markdown]
# <a href="https://colab.research.google.com/github/haithemml/Machine-Learning-with-Python/blob/master/Untitled77.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os

# %%
train_df = pd.read_csv('drive/MyDrive/mobile prediction/train.csv')
test_df = pd.read_csv('drive/MyDrive/mobile prediction/test.csv')

# %%
train_df.shape, test_df.shape
# Out:
# ((2000, 21), (1000, 21))

# %%
train_df.head()
# Out:
#    battery_power  blue  clock_speed  ...  touch_screen  wifi  price_range
# 0            842     0          2.2  ...             0     1            1
# 1           1021     1          0.5  ...             1     0            2
# 2            563     1          0.5  ...             1     0            2
# 3            615     1          2.5  ...             0     0            2
# 4           1821     1          1.2  ...             1     0            1
#
# [5 rows x 21 columns]

# %%
test_df.head()
# Out:
#    id  battery_power  blue  clock_speed  ...  talk_time  three_g  touch_screen  wifi
# 0   1           1043     1          1.8  ...          2        0             1     0
# 1   2            841     1          0.5  ...          7        1             0     0
# 2   3           1807     1          2.8  ...         10        0             1     1
# 3   4           1546     0          0.5  ...          7        1             1     0
# 4   5           1434     0          1.4  ...          7        1             0     1
#
# [5 rows x 21 columns]

# %%
train_df.count()
# Out:
# battery_power    2000
# blue             2000
# clock_speed      2000
# dual_sim         2000
# fc               2000
# four_g           2000
# int_memory       2000
# m_dep            2000
# mobile_wt        2000
# n_cores          2000
# pc               2000
# px_height        2000
# px_width         2000
# ram              2000
# sc_h             2000
# sc_w             2000
# talk_time        2000
# three_g          2000
# touch_screen     2000
# wifi             2000
# price_range      2000
# dtype: int64

# %%
train_df.describe()
# Out:
#        battery_power       blue  ...         wifi  price_range
# count    2000.000000  2000.0000  ...  2000.000000  2000.000000
# mean     1238.518500     0.4950  ...     0.507000     1.500000
# std       439.418206     0.5001  ...     0.500076     1.118314
# min       501.000000     0.0000  ...     0.000000     0.000000
# 25%       851.750000     0.0000  ...     0.000000     0.750000
# 50%      1226.000000     0.0000  ...     1.000000     1.500000
# 75%      1615.250000     1.0000  ...     1.000000     2.250000
# max      1998.000000     1.0000  ...     1.000000     3.000000
#
# [8 rows x 21 columns]

# %%
train_df.isnull().sum().sum()
# Out:
# 0

# %%
y = train_df.price_range
X = train_df.drop(columns=['price_range'], axis=1)

# %%
y.shape, X.shape, test_df.shape
# Out:
# ((2000,), (2000, 20), (1000, 21))

# %%
X['Type'] = 'train_df'
test_df['Type'] = 'test_df'
data = X.append(test_df)

# %%
from sklearn.preprocessing import MinMaxScaler
minmaxscaler = MinMaxScaler()
X_scaled = X.copy()
for cols in X_scaled.columns:
  X_scaled[cols] = X_scaled[cols].min()

# %%
X_scaled.head()
# Out:
#    battery_power  blue  clock_speed  ...  touch_screen  wifi      Type
# 0            501     0          0.5  ...             0     0  train_df
# 1            501     0          0.5  ...             0     0  train_df
# 2            501     0          0.5  ...             0     0  train_df
# 3            501     0          0.5  ...             0     0  train_df
# 4            501     0          0.5  ...             0     0  train_df
#
# [5 rows x 21 columns]

# %%
score_test = []
score_train = []
model = []

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
from sklearn.model_selection import train_test_split
X_train_scaled, X_test_scaled, y_train_scaled, y_test_scaled = train_test_split(X_scaled, y, test_size=0.2, random_state=2)

# %%
train_df.info
# Out:
# <bound method DataFrame.info of       battery_power  blue  clock_speed  ...  touch_screen  wifi  price_range
# 0               842     0          2.2  ...             0     1            1
# 1              1021     1          0.5  ...             1     0            2
# 2               563     1          0.5  ...             1     0            2
# 3               615     1          2.5  ...             0     0            2
# 4              1821     1          1.2  ...             1     0            1
# ...             ...   ...          ...  ...           ...   ...          ...
# 1995            794     1          0.5  ...             1     0            0
# 1996           1965     1          2.6  ...             1     1            2
# 1997           1911     0          0.9  ...             1     0            3
# 1998           1512     0          0.9  ...             1     1            0
# 1999            510     1          2.0  ...             1     1            3
#
# ...

# %%
map(float, train_df)

# %%
results = [float(i) for i in train_df.drop(columns=['battery_power', 'blue', 'clock_speed',
                                                    'dual_sim', 'fc', 'four_g', 'int_memory',
                                                    'm_dep', 'mobile_wt', 'n_cores', 'pc',
                                                    'px_height', 'px_width', 'ram', 'sc_h', 'sc_w',
                                                    'talk_time', 'three_g', 'touch_screen', 'wifi',
                                                    'price_range'], axis=1)]
print(results)
# Out:
# []

# %%
select_df = pd.DataFrame(train_df, columns=['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g', 'int_memory', 'm_dep', 'mobile_wt',
                                            'n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
                                            'touch_screen', 'wifi', 'price_range'])

# %%
select_df.head()
# Out:
#    battery_power  blue  clock_speed  ...  touch_screen  wifi  price_range
# 0            842     0          2.2  ...             0     1            1
# 1           1021     1          0.5  ...             1     0            2
# 2            563     1          0.5  ...             1     0            2
# 3            615     1          2.5  ...             0     0            2
# 4           1821     1          1.2  ...             1     0            1
#
# [5 rows x 21 columns]

# %%
pivot_table = pd.pivot_table(select_df, index=['four_g', 'three_g'])
pivot_table
# Out:
#                 battery_power      blue  ...  touch_screen      wifi
# four_g three_g                           ...
# 0      0          1229.473795  0.522013  ...      0.490566  0.503145
#        1          1233.183333  0.454167  ...      0.497917  0.529167
# 1      1          1245.110259  0.501438  ...      0.511026  0.498562
#
# [3 rows x 19 columns]

# %%
pivot_table.shape
# Out:
# (3, 19)

# %%
pivot_table.reset_index(inplace=True)
pivot_table
# Out:
#    four_g  three_g  battery_power  ...  talk_time  touch_screen      wifi
# 0       0        0    1229.473795  ...  11.427673      0.490566  0.503145
# 1       0        1    1233.183333  ...  11.127083      0.497917  0.529167
# 2       1        1    1245.110259  ...  10.767018      0.511026  0.498562
#
# [3 rows x 21 columns]

# %%
pivot_table.shape
# Out:
# (3, 21)

# %%
pivot_table.sort_values('int_memory', ascending=False).reset_index()
# Out:
#    index  four_g  three_g  ...  talk_time  touch_screen      wifi
# 0      0       0        0  ...  11.427673      0.490566  0.503145
# 1      2       1        1  ...  10.767018      0.511026  0.498562
# 2      1       0        1  ...  11.127083      0.497917  0.529167
#
# [3 rows x 22 columns]

# %%
pivot_table_agg = pd.pivot_table(select_df, index=['four_g', 'three_g'], aggfunc=['mean', 'sum'])
pivot_table_agg
# Out:
#                         mean                        ...       sum
#                battery_power      blue clock_speed  ... talk_time touch_screen wifi
# four_g three_g                                      ...
# 0      0         1229.473795  0.522013    1.589937  ...      5451          234  240
#        1         1233.183333  0.454167    1.528125  ...      5341          239  254
# 1      1         1245.110259  0.501438    1.488591  ...     11230          533  520
#
# [3 rows x 38 columns]

# %%
pivot_table.melt(id_vars=['four_g', 'three_g'])
# Out:
#     four_g  three_g       variable        value
# 0        0        0  battery_power  1229.473795
# 1        0        1  battery_power  1233.183333
# 2        1        1  battery_power  1245.110259
# 3        0        0           blue     0.522013
# 4        0        1           blue     0.454167
# 5        1        1           blue     0.501438
# 6        0        0    clock_speed     1.589937
# 7        0        1    clock_speed     1.528125
# 8        1        1    clock_speed     1.488591
# 9        0        0       dual_sim     0.522013
# 10       0        1       dual_sim     0.493750
# 11       1        1       dual_sim     0.511026
# 12       0        0             fc     4.295597
# 13       0        1             fc     4.472917
# 14       1        1             fc     4.240652
# 15       0        0     int_memory    32.350105
# 16       0        1     int_memory    31.416667
# 17       1        1     int_memory    32.197507
# 18       0        0          m_dep     0.507966
# ...

# %%
pivot_table = pd.pivot_table(select_df, index=['four_g', 'three_g'])
pivot_table.unstack()
# Out:
#         battery_power                   blue  ... touch_screen      wifi
# three_g             0            1         0  ...            1         0         1
# four_g                                        ...
# 0         1229.473795  1233.183333  0.522013  ...     0.497917  0.503145  0.529167
# 1                 NaN  1245.110259       NaN  ...     0.511026       NaN  0.498562
#
# [2 rows x 38 columns]

# %%
unstacked = pivot_table.unstack()
unstacked.stack()
# Out:
#                 battery_power      blue  ...  touch_screen      wifi
# four_g three_g                           ...
# 0      0          1229.473795  0.522013  ...      0.490566  0.503145
#        1          1233.183333  0.454167  ...      0.497917  0.529167
# 1      1          1245.110259  0.501438  ...      0.511026  0.498562
#
# [3 rows x 19 columns]

# %%
train_df.info
# Out:
# <bound method DataFrame.info of       battery_power  blue  clock_speed  ...  touch_screen  wifi  price_range
# 0               842     0          2.2  ...             0     1            1
# 1              1021     1          0.5  ...             1     0            2
# 2               563     1          0.5  ...             1     0            2
# 3               615     1          2.5  ...             0     0            2
# 4              1821     1          1.2  ...             1     0            1
# ...             ...   ...          ...  ...           ...   ...          ...
# 1995            794     1          0.5  ...             1     0            0
# 1996           1965     1          2.6  ...             1     1            2
# 1997           1911     0          0.9  ...             1     0            3
# 1998           1512     0          0.9  ...             1     1            0
# 1999            510     1          2.0  ...             1     1            3
#
# ...

# %%
np.reshape(train_df, (2000, 21))
# Out:
#       battery_power  blue  clock_speed  ...  touch_screen  wifi  price_range
# 0             842.0   0.0          2.2  ...           0.0   1.0          1.0
# 1            1021.0   1.0          0.5  ...           1.0   0.0          2.0
# 2             563.0   1.0          0.5  ...           1.0   0.0          2.0
# 3             615.0   1.0          2.5  ...           0.0   0.0          2.0
# 4            1821.0   1.0          1.2  ...           1.0   0.0          1.0
# ...             ...   ...          ...  ...           ...   ...          ...
# 1995          794.0   1.0          0.5  ...           1.0   0.0          0.0
# 1996         1965.0   1.0          2.6  ...           1.0   1.0          2.0
# 1997         1911.0   0.0          0.9  ...           1.0   0.0          3.0
# 1998         1512.0   0.0          0.9  ...           1.0   1.0          0.0
# 1999          510.0   1.0          2.0  ...           1.0   1.0          3.0
#
# [2000 rows x 21 columns]

# %%
X = train_df.drop('price_range', axis=1)
y = train_df['price_range']

# %%
from sklearn.model_selection import train_test_split
X_train, y_train, X_test, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# %%
pd.DataFrame(list(map(np.ravel, train_df)))
# Out:
#                 0
# 0   battery_power
# 1            blue
# 2     clock_speed
# 3        dual_sim
# 4              fc
# 5          four_g
# 6      int_memory
# 7           m_dep
# 8       mobile_wt
# 9         n_cores
# 10             pc
# 11      px_height
# 12       px_width
# 13            ram
# 14           sc_h
# 15           sc_w
# 16      talk_time
# 17        three_g
# 18   touch_screen
# 19           wifi
# 20    price_range

# %%
np.array(train_df)
# Out:
# array([[8.420e+02, 0.000e+00, 2.200e+00, ..., 0.000e+00, 1.000e+00,
#         1.000e+00],
#        [1.021e+03, 1.000e+00, 5.000e-01, ..., 1.000e+00, 0.000e+00,
#         2.000e+00],
#        [5.630e+02, 1.000e+00, 5.000e-01, ..., 1.000e+00, 0.000e+00,
#         2.000e+00],
#        ...,
#        [1.911e+03, 0.000e+00, 9.000e-01, ..., 1.000e+00, 0.000e+00,
#         3.000e+00],
#        [1.512e+03, 0.000e+00, 9.000e-01, ..., 1.000e+00, 1.000e+00,
#         0.000e+00],
#        [5.100e+02, 1.000e+00, 2.000e+00, ..., 1.000e+00, 1.000e+00,
#         3.000e+00]])

# %%
np.array(train_df).shape
# Out:
# (2000, 21)

# %%
pd.DataFrame(sum(map(list, train_df), []))
# Out:
#      0
# 0    b
# 1    a
# 2    t
# 3    t
# 4    e
# ..  ..
# 143  r
# 144  a
# 145  n
# 146  g
# 147  e
#
# [148 rows x 1 columns]
