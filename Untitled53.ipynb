# %% [markdown]
# <a href="https://colab.research.google.com/github/haithemml/Machine-Learning-with-Python/blob/master/Untitled53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy import ndimage
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
image = plt.imread('cats.png')
image = image[:, :, 0]
plt.imshow(image, cmap='gray')
image.shape
# Out:
# (532, 474)

# %%
image_2 = np.copy(image)
plt.hist(image_2.ravel(), bins=255)
plt.show()

# %%
image=image<0.6
plt.imshow(image)

# %%
open_image = ndimage.binary_opening(image)
plt.imshow(open_image)

# %%
label_image, n_labels = ndimage.label(open_image)
print(f'il y a {n_labels}groupes')
# Out:
# il y a 76groupes

# %%
plt.imshow(label_image)

# %%
sizes=ndimage.sum(open_image, label_image, range(n_labels))

# %%
plt.scatter(range(n_labels), sizes)
plt.xlabel('shadow')
plt.ylabel('relate height')
plt.show()

# %%
x = np.linspace(0, 30, 1000)
y = 3*np.sin(x) + 2*np.sin(5*x) + np.sin(10*x) + np.random.random(x.shape[0])*10
plt.plot(x, y)
